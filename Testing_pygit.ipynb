# %%
# Out:
# [(100755, b6c7ce7026304caf8e2d9eccfad5e9bfde19a18a, 0, favicon.ico),
#  (100644, 64ba74c36068c4aa33a48b23ce8793b5ff06dfd9, 0, index.html),
#  (100644, ddd6adc9bb320422848f66f88d8db3c4a50db434, 0, tangsach.jpeg),
#  (100644, 7ff35e061f6dc069fadad48dea37732a1534a2e0, 0, gift_page.html),
#  (100644, 8d866e1ebe3de025c70e9e88b19578b9aab13217, 0, covid_run_chart.html),
#  (100644, 964abac06d473c0aa118ec3b99a33a87bf447770, 0, covid_data.json),
#  (100644, 45380072e1426feefe088c710479907d4d47cf7c, 0, apache_echart.js),
#  (100644, 78d21780b598ceeaf339b5987bddd4d28a1fd2f6, 0, CNAME),
#  (100644, 5a47094a79fada0b7b158921ffceda1d5d954e55, 0, 197683347_101031325563540_8822030352743346392_n.svg),
#  (100644, c4ed4882dd454c39cd17fbaa96e8eafad92f7f9e, 0, alandao.jpeg),
#  (100644, 5d8e2863614326966e61f81de67c7bd0b98ed0b7, 0, Testing_pygit.ipynb),
#  (100644, f610c0e4ed65801056e88910561b8a39bed33e4d, 0, daily_data_update.py),
#  (100644, 242985728c27646966121b9397b7e93b356bfa7f, 0, index.js),
# ...

# %%
# Out:
# <git.Commit "85cfc203eeccb07f089962987343850229c84f43">

# %%
# Out:
# ''
